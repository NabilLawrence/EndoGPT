# %% [markdown]
# This workbook contains the findings generator and the similarity scores. the output is a dataframe of k findings generated by a fine-tuned model and includes a prompt, the original finding, the generated finding, a classification score corresponding to the predict proba of being a real medical report and a 'originality' score measured as the max cosine distance between the generated findings and the original findings for a given prompt

# %%
from endogpt.Preprocessing import preprocess_real

# %%
from endogpt.Classifier import single_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from endogpt.Classifier import single_text
#
# ModuleNotFoundError: No module named 'endogpt.Classifier'

# %%
#------------------------------------------------------
# Regular modules
#------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import re
#------------------------------------------------------
# To avoid warnings
#------------------------------------------------------
import os
import warnings 
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#------------------------------------------------------
# Specific modules
#------------------------------------------------------
import torch
#from torch import datasets
import umap
import spacy
from transformers import pipeline, set_seed
from transformers import AutoTokenizer, AutoModelForCausalLM

#-------------------------
# Functions called
#--------------------------
